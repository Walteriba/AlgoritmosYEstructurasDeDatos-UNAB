# %% [markdown]
# #  Ejercicios - Clase 04 -

# %% [markdown]
# ## Ejercicio 1:
#
# Qué parametros debemos pasarle al contructor `range`, para producir los valores 8, 6, 4, 2, 0, -2, -4, -6, -8?

# %%
l=[]
for x in range(8,-10,-2):
 l.append(x)
print(l)

# %% [markdown]
# ## Ejercicio 2:
#
# Generarar por comprención la siguiente lista [1, 2, 4, 8, 16, 32, 64, 128, 256].

# %%
lista2=[]
for i in range(0,9):
 lista2.append(2**i)
print(lista2)

# %% [markdown]
# ## Ejercicio 3:
#
#
# Generarar por comprención la siguiente lista `[0, 2, 6, 12, 20, 30, 42, 56, 72, 90]`.
#
# La serie que genera dicha lista es:
#
# $ a_n = a_1 + \sum_{n=1}^{n-1} 2n$
#
# ($n >= 2$ y $a_1 = 0$)

# %%
# lista = [i for i in range(10)] genero una lista utiliza con el for 
lista = [i*(i+1) for i in range(10)]
print(lista)

# %% [markdown]
# ## Ejercicio 4:
#
# Escribir un programa, que tome como entrada un *string* del usuario, el cuál debe ser impreso por pantalla en orden reverso. El programa también debe imprimir la palabra "Bingo!", si el string ingresado es *palíndromo*.

# %%
palabra = input("Ingrese una palabra: ")

# Imprimir la palabra en orden reverso
print("La palabra en orden reverso es:", palabra[::-1])

# Verificar si la palabra es un palíndromo
if palabra == palabra[::-1]:
    print("Bingo! La palabra es un palíndromo.")

# %% [markdown]
# ## Ejercicio 5:
#
# El siguiente código, tener un lista *mess* creada aleatoriamente. Escribir un programa que ordene la lista. **Nota: NO utilizar las funciones provistas por Python**.

# %%
#---------------Code---------------------#
import random                           

mess=[]
N=1000
for p in range(0,N):
    mess.append(random.randrange(0,100000)) 
S=0 
#----------------------------------------#
print(mess)
# Out:
# [72262, 74462, 80525, 84484, 54504, 91077, 4818, 77092, 52980, 25136, 4180, 97693, 19149, 64375, 19858, 76176, 70909, 3090, 33097, 23668, 8978, 20973, 71689, 40926, 94479, 48100, 87040, 44365, 9670, 1618, 65379, 28951, 80238, 83542, 67560, 12783, 8485, 43969, 85728, 87807, 40762, 30477, 78221, 11365, 92181, 75369, 14622, 63806, 48938, 97355, 10463, 43791, 18759, 45876, 21529, 35352, 64665, 65019, 56241, 45043, 3188, 10456, 95977, 3170, 15073, 46873, 81791, 79080, 17972, 67255, 36966, 82859, 39406, 90382, 43593, 97751, 6882, 80523, 72392, 18217, 54937, 82341, 12962, 17279, 53239, 48426, 61706, 76963, 84040, 39508, 65068, 35641, 83738, 3294, 31883, 54388, 73036, 88236, 66341, 47560, 43870, 48238, 52472, 12176, 43683, 77230, 73571, 886, 145, 75526, 78551, 77459, 59528, 79689, 25517, 19446, 38411, 1001, 3707, 16356, 94752, 22203, 96821, 31024, 92642, 8201, 94677, 74168, 18537, 15441, 72683, 9823, 88618, 2398, 34142, 66251, 2262, 25963, 21567, 52964, 22919, 90054, 75623, 63933, 51306, 25903, 46138, 36285, 72617, 18252, 75816, 8063, 6898, 38117, 21041, 11589, 2299, 61616, 10710, 7014, 37603, 37569, 39584, 65408, 45986, 31613, 71218, 63105, 56057, 5
 33097, 33411, 33525, 33582, 33610, 33627, 33743, 33859, 33973, 34091, 34142, 34227, 34286, 34491, 34597, 34674, 34695, 34790, 34865, 35247, 35352, 35570, 35641, 35661, 35669, 35909, 35980, 36094, 36212, 36233, 36285, 36384, 36851, 36953, 36957, 36966, 37159, 37164, 37187, 37292, 37351, 37354, 37444, 37510, 37523, 37569, 37598, 37603, 37721, 37769, 38013, 38090, 38108, 38117, 38117, 38225, 38259, 38411, 38420, 38473, 38497, 38582, 38935, 39095, 39165, 39179, 39243, 39354, 39403, 39406, 39474, 39508, 39533, 39535, 39537, 39584, 39695, 39828, 39923, 40127, 40220, 40487, 40536, 40571, 40624, 40678, 40762, 40788, 40795, 40926, 40931, 40974, 40998, 41208, 41655, 41691, 41856, 41917, 42090, 42119, 42330, 42480, 42483, 42520, 42544, 42689, 42942, 42969, 43057, 43245, 43317, 43458, 43461, 43584, 43593, 43683, 43736, 43755, 43791, 43870, 43969, 44168, 44226, 44283, 44365, 44704, 44754, 44846, 44906, 45043, 45267, 45643, 45675, 45874, 45876, 45935, 45979, 45986, 46138, 46164, 46190, 46226, 46250, 46445, 46602, 46777, 46837, 46873, 46901, 47052, 47062, 47067, 47123, 47152, 47266, 47344, 47421, 47489, 47544, 47560, 47639, 47746, 48100, 48128, 48220, 48238, 48295, 48376, 48411, 48426, 48696, 48938, 49050, 49232, 49389, 49463, 49651, 49713, 49713, 49735, 49786, 49886, 50115, 50323, 50526, 50590, 50646, 50767, 50773, 50923, 51074, 51181, 51306, 51381, 51493, 51600, 52114, 52269, 52472, 52521, 52696, 52964, 52980, 53109, 53151, 53239, 53508, 53593, 53650, 53884, 53985, 54020, 54048, 54379, 54388, 54398, 54491, 54504, 54536, 54661, 54791, 54882, 54932, 54937, 54968, 55162, 55430, 55743, 55789, 56057, 56098, 56234, 56241, 56280, 56427, 56449, 56455, 56741, 56856, 56859, 56860, 56918, 56931, 56932, 56943, 56998, 57243, 57316, 57335, 57658, 57760, 57802, 57849, 57892, 57993, 58 ...

# %% [markdown]
# ## Ejercicio 6:
#
# Escribir un programa que dada una frase (en forma de string) retorne la misma frase, pero con la puntuación removida. Ejemplo: dada la frase *'Hola, buen día.'*, el resultado debe ser *'Hola buen dia'*.

# %%
#Recorrer string con for
#Usar funcion string.punctuation y replace()

# initializing string
test_str = "Hola, como estas?; Yo bien!"

# printing original string
print("The original string is : " + test_str)

# initializing punctuations string
import string
punc = string.punctuation

# Removing punctuations in string
# Using loop + punctuation string
for ele in test_str: 
	if ele in punc:
		test_str = test_str.replace(ele, "") #se reemplaza por nada, el primer argumento es la letra que se reemplza, el segundo con que.

# printing result
print("The string after punctuation filter : " + test_str)
# Out:
# The original string is : Hola, como estas?; Yo bien!
# The string after punctuation filter : Hola como estas Yo bien

# %% [markdown]
# ## Ejercicio 7:
#
# Escribir un programa que tome un número entero `n` y calcule la suma de todos cuadrados de los números menores que `n`.

# %%
n = int(input("Ingrese un numero entero: "))
resultado = 0

for i in range(1 , n):
  resultado += 2**i
print(resultado)
# Out:
# 14
